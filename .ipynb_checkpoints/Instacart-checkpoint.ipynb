# %%
import sqlite3 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Instacart Analysis
#
# ## Exploratory Data Analysis

# %% [markdown]
# accessing database

# %%
conn = sqlite3.connect('instacart.db')

c = conn.cursor()

orders = pd.read_sql_query("SELECT * from orders", conn)
order_products = pd.read_sql_query("SELECT * from order_products", conn)
# products = pd.read_sql_query("SELECT * from products", conn, index_col = "index")
# aisles = pd.read_sql_query("SELECT * from aisles", conn, index_col = "index")
# departments = pd.read_sql_query("SELECT * from departments", conn, index_col = "index")

full_product_info = pd.read_sql_query("SELECT * from products, aisles, departments WHERE products.aisle_id = aisles.aisle_id AND products.department_id = departments.department_id", conn)

c.close()

full_product_info = full_product_info.drop(columns=["index"])
full_product_info.columns = ["product_id", "product_name", "aisle_id", "department_id", "z", "aisle", "z", "department"]
full_product_info = full_product_info.drop(columns=["z"])

# %% [markdown]
# initial look

# %%
print("orders")
print(orders.describe())
print("order_products")
print(order_products.describe())
print("full_product_info")
print(full_product_info.describe())
# Out:
# orders
#            order_id        user_id   order_number      order_dow  \
# count  4.147720e+05  414772.000000  414772.000000  414772.000000
# mean   1.709159e+06  102336.054370      17.245438       2.771788
# std    9.881692e+05   59647.079832      17.801470       2.046092
# min    2.000000e+00       2.000000       1.000000       0.000000
# 25%    8.528778e+05   50325.000000       5.000000       1.000000
# 50%    1.709380e+06  101745.000000      11.000000       3.000000
# 75%    2.564113e+06  154166.000000      24.000000       5.000000
# max    3.421073e+06  206206.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      414772.000000           389772.000000
# mean           13.474299               11.109248
# std             4.228616                9.225167
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# 75%            16.000000               15.000000
# max            23.000000               30.000000
# order_products
#            order_id    product_id  add_to_cart_order     reordered
# count  3.923788e+06  3.923788e+06       3.923788e+06  3.923788e+06
# mean   1.708041e+06  2.556918e+04       8.328105e+00  5.885157e-01
# std    9.883394e+05  1.409081e+04       7.105478e+00  4.921027e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.508580e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.709575e+06  2.521500e+04       6.000000e+00  1.000000e+00
# 75%    2.562477e+06  3.784900e+04       1.100000e+01  1.000000e+00
# max    3.421073e+06  4.968800e+04       1.020000e+02  1.000000e+00
# full_product_info
#          product_id      aisle_id  department_id
# count  49688.000000  49688.000000   49688.000000
# mean   24844.500000     67.769582      11.728687
# std    14343.834425     38.316162       5.850410
# min        1.000000      1.000000       1.000000
# 25%    12422.750000     35.000000       7.000000
# 50%    24844.500000     69.000000      13.000000
# 75%    37266.250000    100.000000      17.000000
# max    49688.000000    134.000000      21.000000

# %%
# print("orders")
# print(orders.head())
# print("order_products")
# print(order_products.head())
# print("full_product_info")
print(full_product_info.head())
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id                       aisle department
# 0             19               cookies cakes     snacks
# 1             13           spices seasonings     pantry
# 2              7                         tea  beverages
# 3              1                frozen meals     frozen
# 4             13  marinades meat preparation     pantry

# %%
# print("orders")
# print(orders.isnull().sum())
# print("order_products")
# print(order_products.isnull().sum())
# print("full_product_info")
# print(full_product_info.isnull().sum())

# %% [markdown]
# looking at orders table

# %%
sns.distplot(orders.order_number, kde = False)
plt.show()

sns.distplot(orders.order_dow, kde = False)
plt.show()

sns.distplot(orders.order_hour_of_day, kde = False)
plt.xticks(range(0,24))
plt.show()

sns.distplot(orders.days_since_prior_order.dropna(), hist = True, kde = False)
plt.show()

# %% [markdown]
# looking at order_products table

# %%
sns.distplot(order_products.add_to_cart_order, kde = False)
plt.show()

sns.distplot(order_products.reordered, kde = False)
plt.xticks([0,1])
plt.show()

# %% [markdown]
# ## Answering Basic Questions

# %%
sellers_order_id = order_products.groupby("product_id").count()["order_id"]
sellers_product_id = np.array([sellers_order_id.index, sellers_order_id.values])

sales_by_product = full_product_info[full_product_info["product_id"].isin(sellers_product_id[0])].assign(n_sales = sellers_order_id.values)
sales_by_product.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id                       aisle department  n_sales
# 0             19               cookies cakes     snacks      231
# 1             13           spices seasonings     pantry       11
# 2              7                         tea  beverages       44
# 3              1                frozen meals     frozen       35
# 4             13  marinades meat preparation     pantry        9

# %%
# top selling products
sales_by_product.nlargest(10, "n_sales")
# Out:
#        product_id            product_name  aisle_id  department_id  \
# 24851       24852                  Banana        24              4
# 13175       13176  Bag of Organic Bananas        24              4
# 21136       21137    Organic Strawberries        24              4
# 21902       21903    Organic Baby Spinach       123              4
# 47208       47209    Organic Hass Avocado        24              4
# 47765       47766         Organic Avocado        24              4
# 47625       47626             Large Lemon        24              4
# 26208       26209                   Limes        24              4
# 16796       16797            Strawberries        24              4
# 27844       27845      Organic Whole Milk        84             16
#
#                             aisle  department  n_sales
# 24851                fresh fruits     produce    58231
# 13175                fresh fruits     produce    45699
# 21136                fresh fruits     produce    32203
# 21902  packaged vegetables fruits     produce    29380
# 47208                fresh fruits     produce    25958
# 47765                fresh fruits     produce    21642
# 47625                fresh fruits     produce    18581
# 26208                fresh fruits     produce    17399
# 16796                fresh fruits     produce    17217
# 27844                        milk  dairy eggs    16468

# %%
print(len(sales_by_product.loc[sales_by_product['n_sales'] == 1])) # number of products that only sold once 
print(len(sales_by_product.loc[sales_by_product['n_sales'] < 0.1 * sales_by_product.n_sales.mean()])) # number of products that sold less than 10% of the average sales per product
# Out:
# 5501
# 20932

# %%
# 80% of sales come from 10% of products
sales_by_product.nlargest(int(.1*len(sales_by_product)), "n_sales")["n_sales"].sum() / sales_by_product["n_sales"].sum()
# Out:
# 0.7940683849382281

# %%
# 6874 products were never ordered
len(full_product_info) - len(sales_by_product)
# Out:
# 6874

# %%
# sales by department
sales_by_product.groupby("department").sum().nlargest(21, "n_sales")
# Out:
#                  product_id  aisle_id  department_id  n_sales
# department
# produce            38715992    126522           6340  1152333
# dairy eggs         78877306    222103          50688   655902
# snacks            136710583    344456         103683   349751
# beverages          92664419    272844          26453   325248
# frozen             90125492    225210           3642   269145
# pantry            116888868    318340          60320   226518
# bakery             35152202    116858           4179   140954
# canned goods       45670524    143749          27945   127249
# deli               29382786     58031          23960   125623
# dry goods pasta    41230688     79379          14832   105315
# household          63205445    217748          44370    89142
# breakfast          25422344    101564          14000    85102
# meat seafood       20611681     58629           9696    84813
# personal care     129143659    320682          57343    54319
# babies             23507299     83036          17226    53448
# international      23922640     53080           5814    32702
# alcohol            19783441     48402           3995    18182
# pets               19260784     31692           6256    11550
# missing            21153468     85000          17850     8253
# other              10540633      2496            832     4226
# bulk                 934060      1916            370     4013

# %%
# top selling aisles
sales_by_product.groupby("aisle").sum().nlargest(10, "n_sales")
# Out:
#                                product_id  aisle_id  department_id  n_sales
# aisle
# fresh fruits                      9066413      8472           1412   443180
# fresh vegetables                 13370145     45235           2180   416040
# packaged vegetables fruits       13738711     70479           2292   214421
# yogurt                           23209499    111960          14928   176682
# packaged cheese                  20722124     17346          13216   117396
# milk                              5750051     18816           3584   109584
# water seltzer sparkling water     7916978     35535           2163   102840
# chips pretzels                   22224133     93946          16682    88132
# soy lactosefree                   6915250     25116           4416    77567
# bread                            12699205     58352           1563    70119

# %%
# bottoms selling aisles
sales_by_product.groupby("aisle").sum().nsmallest(10, "n_sales")
# Out:
#                      product_id  aisle_id  department_id  n_sales
# aisle
# frozen juice             846052      4068             36      554
# beauty                  3218617     16632           1386      754
# baby accessories         795921      2542            558      921
# eye ear care            2252201      3872            968     1046
# baby bath body care     2601372     11934           2106     1048
# kitchen supplies        3564537      1560           2652     1120
# skin care               4738612     22236           2244     1208
# first aid               4588492     22420           2090     1261
# shave needs             4164011      9515           1903     1283
# kosher foods            3130681      4092            744     1372

# %%
# number of users
n_users = len(orders.groupby(["user_id"]).max())
print(n_users)

max_orders_per_user = orders.groupby(["user_id"]).max()
# max_orders_per_user.columns = ["user_id", "order_number"]
# print(max_orders_per_user)

plt.hist(max_orders_per_user["order_number"].values)
plt.xlabel("max orders per user")
plt.ylabel("count")
plt.show()
# Out:
# 25000

# %%
# 50% of users have <= 10 orders
len(max_orders_per_user.loc[max_orders_per_user["order_number"] < 11])/len(max_orders_per_user)
# Out:
#          order_id  order_number  order_dow  order_hour_of_day  \
# user_id
# 2         3268552            15          5                 15
# 8         2979257             4          6                 14
# 11        2921164             8          6                 13
# 12        1916106             6          5                 20
# 28        3331846            25          5                 19
# 31        3352995            21          5                 17
# 36        3285797            38          6                 21
# 47        2906490             6          6                 22
# 62        3349827            11          6                 20
# 67        3205960            25          5                 19
# 69        2817181             6          3                 22
# 70        3087916            14          6                 20
# 80        3348165            13          6                 16
# 101       3084957            21          6                 19
# 104       3268912             6          4                 15
# 105       3204356             8          5                 16
# 113       2438150             6          5                 22
# 114       2880454             5          5                 15
# 115       3347069            13          6                 19
# 119       2268469             4          6                 14
# 125       3283870            14          6                 19
# 129       3203486            12          4                 19
# 134       3081012             7          6                 12
# 144       3264513             8          4                 19
# 147       3266859            14          6                 19
# 160       3159678            13          6                 20
# 173       3403415            45          6                 21
# 179       3125203             6          6                 20
# 192       3155162             6          6                 15
# 212       3218587            13          6                 23
# ...           ...           ...        ...                ...
# 205941    3128548             4          6                 14
# 205944    3308652            22          6                 21
# 205952    3134264             6          5                 14
# 205954    3112505             6          6                 13
# 205961    2340086             7          4                 20
# 205971    3365660            11          2                 17
# 205999    3305261            22          6                 23
# 206001    1801410             5          5                 23
# 206037    3266279            17          5                 21
# 206047    2974715             9          6                 18
# 206053    3322677            61          6                 22
# 206064    3288474             5          5                 19
# 206075    3320767            10          6                 16
# 206093    3370320            18          6                 19
# 206107    3376425            20          6                 18
# 206120    3317783             8          6                 22
# 206123    3290660            29          6                 14
# 206136    3037129            11          6                 20
# 206138    3227112            15          6                 21
# 206143    2801389            11          6                 20
# 206151    3416530            20          6                 22
# 206157    3410055            11          6                 18
# 206158    3301419            51          6                 20
# 206159    2148401             7          5                 14
# 206164    2867531             6          4                 22
# 206194    3395125            12          6                 23
# 206199    3302466            20          6                 22
# 206201    3357192            33          6                 21
# 206202    3378039            23          5                 23
# 206206    3394383            68          6                 20
#
#          days_since_prior_order
# user_id
# 2                          30.0
# 8                          30.0
# 11                         30.0
# 12                         30.0
# 28                         30.0
# 31                         18.0
# 36                         25.0
# 47                         16.0
# 62                         30.0
# 67                         15.0
# 69                         14.0
# 70                         30.0
# 80                         21.0
# 101                        30.0
# 104                        29.0
# 105                        30.0
# 113                        30.0
# 114                        12.0
# 115                        30.0
# 119                        30.0
# 125                        30.0
# 129                        30.0
# 134                        30.0
# 144                        12.0
# 147                        30.0
# 160                        27.0
# 173                        30.0
# 179                        30.0
# 192                        30.0
# 212                        30.0
# ...                         ...
# 205941                     30.0
# 205944                     10.0
# 205952                     30.0
# 205954                     30.0
# 205961                     30.0
# 205971                     30.0
# 205999                     30.0
# 206001                     30.0
# 206037                     30.0
# 206047                     30.0
# 206053                     29.0
# 206064                     26.0
# 206075                     30.0
# 206093                     30.0
# 206107                     30.0
# 206120                     14.0
# 206123                     30.0
# 206136                     16.0
# 206138                     30.0
# 206143                     30.0
# 206151                     30.0
# 206157                     30.0
# 206158                     22.0
# 206159                     30.0
# 206164                     30.0
# 206194                     30.0
# 206199                     30.0
# 206201                     30.0
# 206202                     30.0
# 206206                     15.0
#
# [25000 rows x 5 columns]

# %%
# top 1% of users
top_1_perc_users = max_orders_per_user.nlargest(int(.1*len(max_orders_per_user)), "order_number").index

top_users_order_dow = orders.loc[orders.user_id.isin(top_1_perc_users)].groupby("order_dow").count()
plt.bar(top_users_order_dow["order_id"].index, top_users_order_dow["order_id"].values/sum(top_users_order_dow["order_id"].values))
plt.xlabel("dow")
plt.title("Top 1% users")
plt.show()

top_users_order_hod = orders.loc[orders.user_id.isin(top_1_perc_users)].groupby("order_hour_of_day").count()
plt.bar(top_users_order_hod["order_id"].index, top_users_order_hod["order_id"].values/sum(top_users_order_hod["order_id"].values))
plt.title("Top 1% users")
plt.xlabel("hod")
plt.show()

# orders_of_top_users = orders.loc[orders["user_id"].isin(top_1_perc_users)]
# order_products_top_users = order_products.loc[order_products["order_id"].isin(orders_of_top_users["order_id"])]
# full_product_info.loc[full_product_info["product_id"].isin(order_products_top_users["product_id"])].nlargest(10, )

np.mean(top_users_order_hod["order_id"].index)
# Out:
# 11.5

# %%
# bot 1% of users
bot_1_perc_users = max_orders_per_user.nsmallest(int(.1*len(max_orders_per_user)), "order_number").index

bot_users_order_dow = orders.loc[orders.user_id.isin(bot_1_perc_users)].groupby("order_dow").count()
plt.bar(bot_users_order_dow["order_id"].index, bot_users_order_dow["order_id"].values/sum(bot_users_order_dow["order_id"].values))
plt.xlabel("dow")
plt.title("bot 1% users")
plt.show()

bot_users_order_hod = orders.loc[orders.user_id.isin(bot_1_perc_users)].groupby("order_hour_of_day").count()
plt.bar(bot_users_order_hod["order_id"].index, bot_users_order_hod["order_id"].values/sum(bot_users_order_hod["order_id"].values))
plt.title("bot 1% users")
plt.xlabel("hod")
plt.show()

# %%
stats.ttest_ind(top_users_order_dow["order_id"].index, bot_users_order_dow["order_id"].index)
stats.ttest_ind(top_users_order_hod["order_id"].index, bot_users_order_hod["order_id"].index)
# Out:
# Ttest_indResult(statistic=0.0, pvalue=1.0)

# %%
reorded_pct_by_product = order_products.groupby("product_id").mean()

top_reordered = reorded_pct_by_product.nlargest(10, "reordered")
top_reordered_products = full_product_info.loc[full_product_info["product_id"].isin(top_reordered.index)].assign(reordered_pct = top_reordered["reordered"].values)
print(top_reordered_products)

# bot_reordered = reorded_pct_by_product.nsmallest(10, "reordered")
bot_reordered = reorded_pct_by_product.loc[reorded_pct_by_product["reordered"] < 0.01]
bot_reordered_products = full_product_info.loc[full_product_info["product_id"].isin(bot_reordered.index)].assign(reordered_pct = bot_reordered["reordered"].values)
print(len(bot_reordered_products))
print(len(bot_reordered_products) / len(full_product_info))
# Out:
#        product_id                                    product_name  aisle_id  \
# 6208         6209                                             TAB        77
# 11948       11949                      Sea Salt Bean & Rice Chips       107
# 13284       13285  Organics Second Generation Grain Free Cat Food        41
# 15230       15231                 Beef Pot Roast Home Style Meals        38
# 18732       18733   Pop-Tarts Frosted Red Velvet Toaster Pastries        48
# 20973       20974                   Hickory Smoked Tuna Creations        95
# 26045       26046                             Marinated Mushrooms        81
# 27376       27377                   Shredded Turkey Fare Cat Food        41
# 47560       47561                 All Natural Fresh Chicken Wings        35
# 48616       48617                           Plain New York Bagels        93
#
#        department_id                     aisle    department  reordered_pct
# 6208               7               soft drinks     beverages       0.981481
# 11948             19            chips pretzels        snacks       0.972222
# 13284              8             cat food care          pets       0.972222
# 15230              1              frozen meals        frozen       0.969697
# 18732             14   breakfast bars pastries     breakfast       0.969697
# 20973             15       canned meat seafood  canned goods       0.968750
# 26045             15  canned jarred vegetables  canned goods       0.968750
# 27376              8             cat food care          pets       0.959184
# 47560             12           poultry counter  meat seafood       0.958333
# 48616              3          breakfast bakery        bakery       0.956522
# 12424
# 0.25004025116728384

# %%
# what types of products are added to the cart first?

avg_items_per_order = order_products.groupby("order_id").mean()["add_to_cart_order"]
max_items_per_order = order_products.groupby("order_id").max()["add_to_cart_order"]

plt.hist(max_items_per_order)
plt.xlabel("items in cart at checkout")
plt.show()

med_items = np.median(max_items_per_order)
print(med_items)

num_times_product_added_first = order_products.loc[order_products["add_to_cart_order"] < int(.5 * med_items)].groupby("product_id").count()
print(sum(full_product_info.join(num_times_product_added_first, on = "product_id").nlargest(100, "add_to_cart_order")["product_name"].isin(sales_by_product.nlargest(100, "n_sales")["product_name"]))/100)

print(sum(full_product_info.join(num_times_product_added_first, on = "product_id").nsmallest(100, "add_to_cart_order")["product_name"].isin(sales_by_product.nsmallest(100, "n_sales")["product_name"]))/100)
# Out:
# 8.0
# 0.82
# 0.09

# %%
orders.days_since_prior_order.isnull().sum() / len(orders)

len(orders.loc[orders.days_since_prior_order == 30]) / len(orders)

mean_days_since_prior_order = orders.groupby("user_id").mean()
mean_days_since_prior_order.days_since_prior_order.mean()
len(mean_days_since_prior_order.loc[mean_days_since_prior_order.days_since_prior_order < 21]) / len(mean_days_since_prior_order)

# min_days_since_prior_order = orders.groupby("user_id").min()
# len(min_days_since_prior_order.loc[min_days_since_prior_order.days_since_prior_order == 30].groupby("user_id").count()) / len(orders.groupby("user_id").count())
# Out:
# 0.75888

# %%
# order_products.groupby(["order_id"])['product_id'].apply(list).to_dict()
order_products.loc[order_products.product_id.isin(sales_by_product.nlargest(100, "n_sales")["product_id"])]
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 1               2       28985                  2          1
# 5               2       17794                  6          1
# 22             15       19660                  1          1
# 27             19       42265                  1          1
# 28             19       24838                  2          1
# 30             27       13176                  1          1
# 36             27       47766                  7          1
# 37             27       17794                  8          1
# 39             27       21938                 10          0
# 45             27       28985                 16          1
# 53             27       41950                 24          1
# 58             52       24852                  2          1
# 60             52       49683                  4          1
# 65             62       26209                  4          0
# 66             62       47766                  5          0
# 68             62       20114                  7          0
# 74            102       29487                  1          1
# 76            102       27966                  3          0
# 78            102       27104                  5          0
# 84            111       16797                  1          1
# 88            111       49683                  5          1
# 103           130       24852                  5          0
# 107           130       19057                  9          0
# 109           130       34358                 11          0
# 111           130       35221                 13          0
# 113           134       43961                  1          0
# 131           139       19678                  2          1
# 132           139       22935                  3          1
# 133           139       21903                  4          1
# 134           139       33731                  5          1
# ...           ...         ...                ...        ...
# 3923636   3420875        4210                  1          1
# 3923637   3420875       23909                  2          1
# 3923638   3420880       13176                  1          1
# 3923641   3420880       46667                  4          0
# 3923646   3420905       37646                  3          1
# 3923647   3420905        5876                  4          1
# 3923650   3420905       41220                  7          1
# 3923653   3420905        9839                 10          1
# 3923654   3420905       39275                 11          1
# 3923665   3420956       28204                  2          1
# 3923666   3420957         196                  1          0
# 3923700   3420970       23909                  2          0
# 3923701   3421002       21137                  1          1
# 3923703   3421002       13176                  3          1
# 3923707   3421002       27344                  7          1
# 3923710   3421002        5077                 10          1
# 3923713   3421002        9076                 13          0
# 3923725   3421003       47766                  4          1
# 3923731   3421003       30391                 10          0
# 3923733   3421008       47209                  2          1
# 3923735   3421008       43961                  4          0
# 3923739   3421020        5785                  3          1
# 3923744   3421020       17794                  8          0
# 3923747   3421027       24852                  3          1
# 3923748   3421027       46906                  4          1
# 3923749   3421027       28204                  5          1
# 3923757   3421029       28199                  1          1
# 3923767   3421029       47766                 11          1
# 3923770   3421047       47766                  3          1
# 3923772   3421047       20114                  5          1
#
# [907927 rows x 4 columns]

# %%
orders_of_best_sellers = order_products.loc[order_products.product_id.isin(sales_by_product.nlargest(50, "n_sales")["product_id"])]
orders_of_best_sellers_name = orders_of_best_sellers.merge(full_product_info, on = "product_id")
encoded_order_products = orders_of_best_sellers_name.groupby(["order_id", "product_name"])['add_to_cart_order'].sum().unstack().reset_index().fillna(0).set_index('order_id')

def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
OH_encoded_order_products = encoded_order_products.applymap(encode_units)

frequent_itemsets = apriori(OH_encoded_order_products, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.1)

# “Frequently Bought Together”
# support - default popularity of an item. ratio of transactions involving A to the total number of transactions
# confidence - Likelihood that customer who bought both A and B
# lift - Increase in the sale of A when you sell B
rules.head()
# Out:
#                   antecedents                 consequents  antecedent support  \
# 0  (Apple Honeycrisp Organic)    (Bag of Organic Bananas)            0.040776
# 1    (Bag of Organic Bananas)  (Apple Honeycrisp Organic)            0.181656
# 2    (Bag of Organic Bananas)      (Organic Baby Spinach)            0.181656
# 3      (Organic Baby Spinach)    (Bag of Organic Bananas)            0.116787
# 4       (Organic Blueberries)    (Bag of Organic Bananas)            0.047788
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.181656  0.011297    0.277052  1.525147  0.003890    1.131954
# 1            0.040776  0.011297    0.062190  1.525147  0.003890    1.022833
# 2            0.116787  0.024892    0.137027  1.173307  0.003677    1.023454
# 3            0.181656  0.024892    0.213138  1.173307  0.003677    1.040010
# 4            0.181656  0.010431    0.218267  1.201538  0.001750    1.046833

# %%
rules.nlargest(10, "lift")
# Out:
#                antecedents             consequents  antecedent support  \
# 54        (Organic Garlic)  (Organic Yellow Onion)            0.052220
# 55  (Organic Yellow Onion)        (Organic Garlic)            0.053087
# 38           (Large Lemon)                 (Limes)            0.073860
# 39                 (Limes)           (Large Lemon)            0.069162
# 60  (Organic Strawberries)   (Organic Raspberries)            0.128009
# 61   (Organic Raspberries)  (Organic Strawberries)            0.064416
# 52   (Organic Blueberries)  (Organic Strawberries)            0.047788
# 53  (Organic Strawberries)   (Organic Blueberries)            0.128009
# 56  (Organic Hass Avocado)   (Organic Raspberries)            0.103184
# 57   (Organic Raspberries)  (Organic Hass Avocado)            0.064416
#
#     consequent support   support  confidence      lift  leverage  conviction
# 54            0.053087  0.010415    0.199437  3.756802  0.007642    1.182809
# 55            0.052220  0.010415    0.196181  3.756802  0.007642    1.179096
# 38            0.069162  0.013797    0.186804  2.700961  0.008689    1.144666
# 39            0.073860  0.013797    0.199494  2.700961  0.008689    1.156943
# 60            0.064416  0.016210    0.126634  1.965889  0.007964    1.071240
# 61            0.128009  0.016210    0.251651  1.965889  0.007964    1.165220
# 52            0.128009  0.011389    0.238313  1.861696  0.005271    1.144816
# 53            0.047788  0.011389    0.088967  1.861696  0.005271    1.045200
# 56            0.064416  0.012323    0.119424  1.853952  0.005676    1.062468
# 57            0.103184  0.012323    0.191299  1.853952  0.005676    1.108958

# %%
np.random.seed(1)
random_order_ids = full_product_info["product_id"].sample(100)
random_orders = order_products.loc[order_products.product_id.isin(random_order_ids.values)]
random_orders_names = random_orders.merge(full_product_info, on = "product_id")
encoded_random_orders_names = random_orders_names.groupby(["order_id", "product_name"])['add_to_cart_order'].sum().unstack().reset_index().fillna(0).set_index('order_id')
OH_encoded_random_orders_names = encoded_random_orders_names.applymap(encode_units)

frequent_itemsets2 = apriori(OH_encoded_random_orders_names, min_support=0.0001, use_colnames=True)
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)

# %%
rules2.nlargest(10, "lift")
# Out:
#                                          antecedents  \
# 4  (Organic Stage 2 Veggie & Protein Puree Brocco...
# 5                      (Organic Unsweetened Ketchup)
# 2                     (Soft French-Style Nut Cheese)
# 3        (Hickory Honey Barbeque Baked Potato Chips)
# 0  (Flourless  Sprouted Whole Grain 7-Sprouted Gr...
# 1                                  (Chicken Burgers)
#
#                                          consequents  antecedent support  \
# 4                      (Organic Unsweetened Ketchup)            0.007732
# 5  (Organic Stage 2 Veggie & Protein Puree Brocco...            0.005778
# 2        (Hickory Honey Barbeque Baked Potato Chips)            0.003824
# 3                     (Soft French-Style Nut Cheese)            0.012151
# 0                                  (Chicken Burgers)            0.030929
# 1  (Flourless  Sprouted Whole Grain 7-Sprouted Gr...            0.001784
#
#    consequent support  support  confidence      lift  leverage  conviction
# 4            0.005778  0.00017    0.021978  3.803814  0.000125    1.016564
# 5            0.007732  0.00017    0.029412  3.803814  0.000125    1.022337
# 2            0.012151  0.00017    0.044444  3.657809  0.000123    1.033796
# 3            0.003824  0.00017    0.013986  3.657809  0.000123    1.010307
# 0            0.001784  0.00017    0.005495  3.079278  0.000115    1.003731
# 1            0.030929  0.00017    0.095238  3.079278  0.000115    1.071079
